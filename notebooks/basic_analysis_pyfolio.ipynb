# %%
import pyfolio as pf
import datetime
import matplotlib
# %matplotlib inline

# %%
stock_rets = pf.utils.get_symbol_rets('FB')

# %%
pf.create_returns_tear_sheet(stock_rets)
# Out:
# Entire data start date: 2012-05-21
# Entire data end date: 2020-07-13
#
#
# Backtest Months: 97
# Performance statistics   Backtest
# annual_return                0.25
# annual_volatility            0.37
# sharpe_ratio                 0.79
# calmar_ratio                 0.53
# stability_of_timeseries      0.93
# max_drawdown                -0.48
# omega_ratio                  1.17
# sortino_ratio                1.19
# skew                         0.98
# kurtosis                    19.90
# tail_ratio                   1.05
# common_sense_ratio           1.31
# information_ratio            0.03
# alpha                        0.14
# beta                         1.06
# Worst Drawdown Periods net drawdown in %  peak date valley date recovery date  \
# 0                                  47.90 2012-05-21  2012-09-04    2013-07-25
# 1                                  42.96 2018-07-25  2018-12-24    2020-01-09
# 2                                  34.59 2020-01-29  2020-03-16    2020-05-20
# ...
